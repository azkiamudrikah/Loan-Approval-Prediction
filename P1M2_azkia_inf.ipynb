# %% [markdown]
# # Perkenalan
#
# Azkia Mudrikah
# RMT 036
# Data Inference
#
# Model Inference dibuat untuk memprediksi data baru menggunakan model machine learning yang sudah dibuat dan dilatih sebelumnya.

# %% [markdown]
# # Import Libraries

# %% [markdown]
# Bagian ini berisi modul yang digunakan pada model inference

# %%
import pandas as pd
import pickle

# %% [markdown]
# # Load Model

# %% [markdown]
# Model terbaik pada hasil pembuatan machine learning diimport ke model inference untuk memprediksi data baru.

# %%
# membuka model yang telah disimpan
with open('best_model.pkl', 'rb') as file_1:
  best_result = pickle.load(file_1)

# %% [markdown]
# Menampilkan model

# %%
best_result
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['education_level',
#                                                    'home_ownership_status']),
#                                                  ('num', StandardScaler(),
#                                                   ['age', 'annual_income',
#                                                    'credit_score', 'experience',
#                                                    'loan_amount',
#                                                    'loan_duration',
#                                                    'number_of_dependents',
#                                                    'monthly_debt_payments',
# ...

# %% [markdown]
# # Input data baru

# %% [markdown]
# Data baru yang akan diprediksi diinput pada bagian ini.

# %%
# input data
data = {
    'application_date':'2024-08-29', 
    'age':55, 
    'annual_income':50000, 
    'credit_score':375,
    'employment_status':'Employed', 
    'education_level':'Bachelor', 
    'experience':27, 
    'loan_amount':30564,
    'loan_duration':36, 
    'marital_status':'Married', 
    'number_of_dependents':7,
    'home_ownership_status':'Own', 
    'monthly_debt_payments':627,
    'credit_card_utilization_rate':0.123, 
    'number_of_open_credit_lines':2,
    'number_of_credit_inquiries':0, 
    'debt_to_income_ratio':0.27,
    'bankruptcy_history':0, 
    'loan_purpose':'Education', 
    'previous_loan_defaults':0,
    'payment_history':27, 
    'length_of_credit_history':17,
    'savings_account_balance':5647, 
    'checking_account_balance':589, 
    'total_assets':22503,
    'total_liabilities':19273, 
    'monthly_income':4536.32, 
    'utility_bills_payment_history':0.347,
    'job_tenure':13, 
    'net_worth':3453, 
    'base_interest_rate':0.31, 
    'interest_rate':0.29,
    'monthly_loan_payment':598.98, 
    'total_debt_to_income_ratio':0.32, 
    'risk_score':75.0
}
# memasukkan data ke dalam dataframe
df = pd.DataFrame.from_dict([data])

# %%
# menampilkan data
df
# Out:
#   application_date  age  annual_income  credit_score employment_status  \
# 0       2024-08-29   55          50000           375          Employed
#
#   education_level  experience  loan_amount  loan_duration marital_status  ...  \
# 0        Bachelor          27        30564             36        Married  ...
#
#    total_liabilities monthly_income  utility_bills_payment_history  \
# 0              19273        4536.32                          0.347
#
#    job_tenure  net_worth  base_interest_rate  interest_rate  \
# 0          13       3453                0.31           0.29
#
#    monthly_loan_payment total_debt_to_income_ratio  risk_score
# 0                598.98                       0.32        75.0
#
# [1 rows x 35 columns]

# %% [markdown]
# Setelah data dimasukkan ke dalam dataframe, selanjutnya data diprediksi menggunakan model machine learning

# %%
# memprediksi data menggunakan machine learning
prediction = best_result.predict(df)
# kondisi untuk menyatakan hasil prediksi
if prediction == 1:
    print('Selamat, pinjaman anda disetujui!')
else:
    print('Mohon maaf pinjaman anda belum dapat kami setujui')
# Out:
# Mohon maaf pinjaman anda belum dapat kami setujui

# %% [markdown]
# Berdasarkan faktor-faktor yang sudah diinput pada model, hasil prediksi menyatakan bahwa pengajuan pinjaman oleh nasabah dengan data tersebut tidak akan disetujui.
